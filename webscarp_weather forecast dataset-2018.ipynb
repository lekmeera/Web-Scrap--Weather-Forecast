# %%
import pandas as pd
import html5lib

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/1.html'
dfs = pd.read_html(url,header=0)
df = pd.concat(dfs)
df = df.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df.rename(columns={"January": "Month","2018":"Year"},inplace=True)
values = {'Month': 'Jan','Year':'2018'}
df = df.fillna(value=values)

df = df[:31]
df.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day FG    H India Month   PP   RA     SLP   SN     T    TM   TS   Tm  \
# 0  2018   1  o   88   NaN   Jan    0  NaN  1014.5  NaN  12.2  23.9  NaN  5.7
# 1  2018   2  o   89   NaN   Jan    0  NaN  1015.3  NaN  11.8  20.1  NaN  8.4
# 2  2018   3  o   85   NaN   Jan    0  NaN  1015.6  NaN  11.3  18.2  NaN  6.7
# 3  2018   4  o  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 4  2018   5  o  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN  NaN
#
#      V   VG   VM   VV Weather
# 0  0.7    -  5.4  0.3     NaN
# 1  2.8    -  9.4  0.3     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/2.html'
dfs = pd.read_html(url,header=0)
df1 = pd.concat(dfs)

df1 = df1.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df1.rename(columns={"February": "Month","2018":"Year"},inplace=True)
values = {'Month': 'Feb','Year':'2018'}
df1 = df1.fillna(value=values)

df1 = df1[:28]
df1
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Year Day   FG Month    H India   PP   RA     SLP   SN     T    TM   TS  \
# 0   2018   1  NaN   Feb   69   NaN    0  NaN  1013.9  NaN  18.7  27.2  NaN
# 1   2018   2  NaN   Feb   69   NaN    0  NaN  1012.7  NaN  17.7  27.8  NaN
# 2   2018   3  NaN   Feb   57   NaN    0  NaN  1015.4  NaN    16  26.5  NaN
# 3   2018   4  NaN   Feb  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4   2018   5  NaN   Feb  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 5   2018   6  NaN   Feb  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/3.html'
dfs = pd.read_html(url,header=0)
df2 = pd.concat(dfs)
df2 = df2.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df2.rename(columns={"March": "Month","2018":"Year"},inplace=True)
values = {'Month': 'Mar','Year':'2018'}
df2 = df2.fillna(value=values)

df2 = df2[:31]
df2.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month   PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   62   NaN   Mar    0  NaN  1010.8  NaN  21.7  30.7  NaN
# 1  2018   2  NaN   58   NaN   Mar    0  NaN    1009  NaN  22.9    31  NaN
# 2  2018   3  NaN   53   NaN   Mar    0  NaN  1006.9  NaN  24.1  32.3  NaN
# 3  2018   4  NaN  NaN   NaN   Mar  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   Mar  NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm    V   VG    VM   VV Weather
# 0  14.9  1.7    -   7.6  1.6     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/4.html'
dfs = pd.read_html(url,header=0)
df3 = pd.concat(dfs)
df3 = df3.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df3.rename(columns={"April": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Apr','Year':'2018'}
df3 = df3.fillna(value=values)

df3 = df3[:30]
df3.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Month Day   FG    H India   PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   Apr   1  NaN   52   NaN    0  NaN  1008.6  NaN  27.8  34.8  NaN
# 1  2018   Apr   2  NaN   53   NaN    0  NaN    1009  NaN  27.6  36.2  NaN
# 2  2018   Apr   3  NaN   49   NaN    0  NaN  1007.2  NaN  29.4  38.2  NaN
# 3  2018   Apr   4  NaN  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   Apr   5  NaN  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm    V   VG    VM   VV Weather
# 0    20  6.1    -  11.1  2.7     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/5.html'
dfs = pd.read_html(url,header=0)
df4 = pd.concat(dfs)

df4 = df4.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df4.rename(columns={"May": "Month","2018":"Year"},inplace=True)

values = {'Month': 'May','Year':'2018'}
df4 = df4.fillna(value=values)

df4 = df4[:31]
df4.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month     PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   52   NaN   May      0  NaN  1003.4  NaN  31.7    40  NaN
# 1  2018   2  NaN   59   NaN   May  12.95    o  1004.7  NaN  28.8  37.6  NaN
# 2  2018   3  NaN   52   NaN   May      0  NaN  1005.8  NaN  29.6  34.2  NaN
# 3  2018   4  NaN  NaN   NaN   May    NaN    o     NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   May    NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm     V    VG    VM   VV Weather
# 0  26.5    10     -  14.8  2.7     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/6.html'
dfs = pd.read_html(url,header=0)
df5 = pd.concat(dfs)

df5 = df5.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df5.rename(columns={"June": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Jun','Year':'2018'}
df5 = df5.fillna(value=values)

df5 = df5[:30]
df5.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month   PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   50   NaN   Jun    0  NaN  1000.7  NaN  34.6  42.1  NaN
# 1  2018   2  NaN   53   NaN   Jun    0  NaN  1001.6  NaN  32.3    42  NaN
# 2  2018   3  NaN   56   NaN   Jun    0  NaN   998.6  NaN    34  39.2  NaN
# 3  2018   4  NaN  NaN   NaN   Jun  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   Jun  NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm     V   VG    VM   VV Weather
# 0  28.4  12.8    -  33.5  2.6     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/7.html'
dfs = pd.read_html(url,header=0)
df6 = pd.concat(dfs)

df6 = df6.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df6.rename(columns={"July": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Jul','Year':'2018'}
df6 = df6.fillna(value=values)

df6 = df6[:31]
df6.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month    PP   RA    SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   68   NaN   Jul     0  NaN  997.2  NaN  32.6  36.2  NaN
# 1  2018   2  NaN   66   NaN   Jul  22.1    o  995.6  NaN  31.2  37.4    o
# 2  2018   3  NaN   70   NaN   Jul     0  NaN  995.7  NaN  32.1  37.8  NaN
# 3  2018   4  NaN  NaN   NaN   Jul   NaN    o    NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   Jul   NaN  NaN    NaN  NaN   NaN   NaN  NaN
#
#      Tm     V   VG    VM   VV Weather
# 0    29  11.9    -  22.2  1.9     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/8.html'
dfs = pd.read_html(url,header=0)
df7 = pd.concat(dfs)

df7 = df7.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df7.rename(columns={"August": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Aug','Year':'2018'}
df7 = df7.fillna(value=values)

df7 = df7[:31]
df7.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Month Day   FG    H India    PP   RA    SLP   SN     T    TM   TS  \
# 0  2018   Aug   1  NaN   71   NaN  0.51  NaN    997  NaN  31.5    35  NaN
# 1  2018   Aug   2  NaN   67   NaN     0  NaN  998.3  NaN  32.1  35.6  NaN
# 2  2018   Aug   3  NaN   68   NaN     0  NaN  998.6  NaN  31.5  35.8  NaN
# 3  2018   Aug   4  NaN  NaN   NaN   NaN  NaN    NaN  NaN   NaN   NaN  NaN
# 4  2018   Aug   5  NaN  NaN   NaN   NaN    o    NaN  NaN   NaN   NaN  NaN
#
#      Tm     V   VG    VM   VV Weather
# 0    26     5    -  14.8  2.7     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/9.html'
dfs = pd.read_html(url,header=0)
df8 = pd.concat(dfs)

df8 = df8.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df8.rename(columns={"September": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Sep','Year':'2018'}
df8 = df8.fillna(value=values)

df8 = df8[:30]
df8.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India     PP RA     SLP   SN Month     T    TM   TS  \
# 0  2018   1  NaN   93   NaN  24.89  o  1002.6  NaN   Sep  27.1    34    o
# 1  2018   2  NaN   92   NaN  24.89  o  1002.3  NaN   Sep  26.7  29.4  NaN
# 2  2018   3  NaN   95   NaN  36.07  o  1002.4  NaN   Sep  26.7    29  NaN
# 3  2018   4  NaN  NaN   NaN    NaN  o     NaN  NaN   Sep   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN    NaN  o     NaN  NaN   Sep   NaN   NaN  NaN
#
#      Tm    V   VG    VM   VV Weather
# 0  23.5  4.8    -  16.5  1.8     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/10.html'
dfs = pd.read_html(url,header=0)
df9 = pd.concat(dfs)

df9 = df9.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df9.rename(columns={"October": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Oct','Year':'2018'}
df9 = df9.fillna(value=values)

df9 = df9[:31]
df9.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month   PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   66   NaN   Oct    0  NaN  1008.4  NaN  28.2  34.8  NaN
# 1  2018   2  NaN   63   NaN   Oct    0  NaN  1008.8  NaN  28.7  35.2  NaN
# 2  2018   3  NaN   59   NaN   Oct    0  NaN  1008.5  NaN  28.8  35.6  NaN
# 3  2018   4  NaN  NaN   NaN   Oct  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   Oct  NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm    V   VG   VM   VV Weather
# 0  22.2  2.6    -  9.4  2.7     NaN
# 1  22.5  0.4    -  3.5  2.6     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/11.html'
dfs = pd.read_html(url,header=0)
df10 = pd.concat(dfs)

df10 = df10.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df10.rename(columns={"November": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Nov','Year':'2018'}
df10 = df10.fillna(value=values)

df10 = df10[:30]
df10.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day   FG    H India Month    PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1  NaN   65   NaN   Nov     0  NaN  1014.3  NaN  24.1  31.1  NaN
# 1  2018   2  NaN   63   NaN   Nov     0  NaN  1012.1  NaN  24.6    32  NaN
# 2  2018   3  NaN   63   NaN   Nov  0.25  NaN  1011.7  NaN  25.2  31.6  NaN
# 3  2018   4  NaN  NaN   NaN   Nov   NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   5  NaN  NaN   NaN   Nov   NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm    V   VG    VM   VV Weather
# 0    16    5    -  14.4  1.6     NaN
# ...

# %%
url = 'file:///D:/excercises%20python/Projects/tutiempo-climate/2018/12.html'
dfs = pd.read_html(url,header=0)
df11 = pd.concat(dfs)

df11 = df11.drop(columns=['Asia','Average Temperature (°C)','Climate','Climate New Delhi / Safdarjung'])

df11.rename(columns={"December": "Month","2018":"Year"},inplace=True)

values = {'Month': 'Dec','Year':'2018'}
df11 = df11.fillna(value=values)

df11 = df11[:31]
df11.head()
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Year Day Month   FG    H India   PP   RA     SLP   SN     T    TM   TS  \
# 0  2018   1   Dec  NaN   60   NaN    0  NaN       -  NaN  19.6  26.4  NaN
# 1  2018   2   Dec  NaN   56   NaN    0  NaN  1014.6  NaN  19.6    28  NaN
# 2  2018   3   Dec  NaN   58   NaN    0  NaN  1016.7  NaN  18.9  28.1  NaN
# 3  2018   4   Dec  NaN  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
# 4  2018   5   Dec  NaN  NaN   NaN  NaN  NaN     NaN  NaN   NaN   NaN  NaN
#
#      Tm    V   VG    VM   VV Weather
# 0  10.8  5.4    -  14.8  2.6     NaN
# ...

# %%
result = df.append([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11])

result.head(60)
# Out:
#    Day   FG    H India Month   PP   RA     SLP   SN     T    TM   TS    Tm  \
# 0    1    o   88   NaN   Jan    0  NaN  1014.5  NaN  12.2  23.9  NaN   5.7
# 1    2    o   89   NaN   Jan    0  NaN  1015.3  NaN  11.8  20.1  NaN   8.4
# 2    3    o   85   NaN   Jan    0  NaN  1015.6  NaN  11.3  18.2  NaN   6.7
# 3    4    o  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN   NaN
# 4    5    o  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN   NaN
# 5    6    o  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN   NaN
# 6    7    o   69   NaN   Jan    0  NaN  1015.2  NaN  13.2  20.8  NaN   6.4
# 7    8  NaN   72   NaN   Jan    0  NaN  1017.6  NaN  12.1  20.7  NaN     5
# 8    9    o   75   NaN   Jan    0  NaN  1019.1  NaN  12.2  21.7  NaN   4.2
# 9   10  NaN  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN   NaN
# 10  11  NaN  NaN   NaN   Jan  NaN  NaN     NaN  NaN   NaN   NaN  NaN   NaN
# ...

# %%
result.to_csv("weather forecast dataset-2018.csv",index = False,header = True)
